# %%
import os, sys, json
import numpy as np

self_dir = os.getcwd()
root_dir = os.path.normpath(self_dir + '/..' * 2)
package_dir = os.path.join(root_dir, 'src')
sys.path.append(package_dir)

from ml_modules.data.retrievers import UniProt_Retriever

kb_dir = '../../data/external/UniProt/kb'

retriever = UniProt_Retriever()

coupling_types = ['codir', 'coord', 'deform']
edge_types = ['contact'] + coupling_types

tag = '20250805'

n_entries_to_process = 150

# %%
src_dir = '../20250526-1 true and baseline vs dynamics performance/stats'

src_list = [
    f'{src_dir}/accessions - largest improvement (baseline 0 vs dynamics 4).csv',
    f'{src_dir}/accessions - largest improvement (baseline 1 vs dynamics 4).csv',
    f'{src_dir}/accessions - largest improvement (baseline 2 vs dynamics 4).csv',
]

stats_dir = f'stats'
os.makedirs(stats_dir, exist_ok=True)

accessions = {
    src_file: np.loadtxt(
        os.path.abspath(src_file),
        usecols=0,
        delimiter=',',
        dtype=np.str_
    )[:n_entries_to_process] for src_file in src_list
}
print(accessions)
# Out:
# {'../20250526-1 true and baseline vs dynamics performance/stats/accessions - largest improvement (baseline 0 vs dynamics 4).csv': array(['Q6L225', 'Q72IP3', 'Q72L85', 'Q72I39', 'Q6L2H9', 'P02930',
#        'O34687', 'Q6L0G3', 'P0A8U0', 'Q6L2R6', 'P40423', 'Q72GB7',
#        'Q72J05', 'Q8MQ13', 'P23715', 'Q6L1M5', 'Q6L2G4', 'Q3U7Z6',
#        'P28707', 'P28248', 'P61526', 'Q9RA61', 'Q20574', 'O76075',
#        'P32939', 'P0A794', 'P25294', 'Q72IH1', 'P30750', 'Q6KZF2',
#        'P61981', 'Q72J82', 'Q9LQK7', 'Q6L2P7', 'P09029', 'Q9NZL9',
#        'O04420', 'Q8BPE4', 'Q46893', 'Q72GD0', 'I2HA94', 'Q9XWN1',
#        'P09372', 'P0A6J8', 'Q9VX88', 'P0AFE4', 'Q96AD5', 'Q9XTX0',
#        'Q6L1Q5', 'P0ACN7', 'P09734', 'P35659', 'P75853', 'Q72HR4',
#        'P61221', 'Q00059', 'Q72JU0', 'Q9DB28', 'O16406', 'Q72GB9',
#        'Q9FH05', 'Q3UI84', 'Q93168', 'Q21557', 'Q6L1U0', 'Q9CQ54',
#        'Q6L2P6', 'Q8L7B2', 'O80934', 'P36771', 'P53040', 'P02394',
#        'P54167', 'P54819', 'Q93WN0', 'Q72HM0', 'Q17352', 'P0A7J3',
#        'Q96522', 'Q72HZ7', 'O08914', 'Q6L1W5', 'O62431', 'P49723',
#        'Q99KS2', 'A3FPI6', 'Q9DCJ5', 'Q9VH89', 'Q745W2', 'O31775',
#        'Q72HH2', 'P03813', 'Q12362', 'Q6L084', 'O23553', 'Q72HA0',
#        'Q09389', 'P55734', 'Q9CQX6', 'Q72K74', 'O75529', 'Q6L0G0',
#        'Q6L2K5', 'P77581', 'Q72KV4', 'Q6L0J8', 'Q6L0X5', 'P53867',
#        'Q72GX0', 'P34460', 'Q8BZ36', 'Q8N9V3', 'F8WIT2', 'Q9UHN1',
#        'P30177', 'R4YUC2', 'Q20520', 'Q9FKM2', 'Q95XP9', 'Q80WS3',
#        'P39814', 'Q3UY68', 'Q7YTY6', 'P40161', 'Q94517', 'Q05031',
#        'P03899', 'Q966C7', 'Q545U2', 'P21365', 'P0A8W0', 'P28305',
#        'P39522', 'Q9ER38', 'F1RET2', 'G5EFJ5', 'P16371', 'P15565',
#        'Q8K2B3', 'P01123', 'Q9V7N5', 'Q5U458', 'P38646', 'Q9VMP9',
#        'Q72H86', 'Q9GYR2', 'Q6L1H5', 'Q7TMK6', 'Q72HI8', 'P48036'],
#       dtype='<U10'), '../20250526-1 true and baseline vs dynamics performance/stats/accessions - largest improvement (baseline 1 vs dynamics 4).csv': array(['A7MCK9', 'Q3E754', 'P0AFX4', 'P21365', 'P75853', 'Q7ZWE5',
#        'Q6L2P6', 'P00903', 'P00358', 'P33204', 'Q6Q546', 'P02929',
#        'Q6L1Q5', 'P28707', 'Q7ZU67', 'A2BE93', 'B2GTW6', 'Q6L0Y5',
#        'Q6L2L7', 'P54167', 'O08914', 'P07487', 'P0A8U0', 'Q6L2H9',
#        'Q6L225', 'P42677', 'Q9D1H6', 'Q93168', 'P09734', 'P0CF20',
#        'Q9UHN1', 'R4YQ94', 'O76075', 'Q8BPE4', 'P28248', 'Q8W4H7',
#        'P53145', 'O31775', 'Q7T3G2', 'Q20574', 'Q9LY74', 'Q9XWN1',
#        'R4YPI8', 'P32939', 'A1Z7A8', 'Q72K10', 'P32795', 'Q8MQ13',
#        'P0AG40', 'Q6KYU0', 'P15624', 'Q8BTU1', 'Q6L322', 'P13056',
#        'Q7TMK6', 'P94369', 'P62258', 'Q6L0G3', 'Q9BSB4', 'Q3UY68',
#        'Q9H0U4', 'Q3UI84', 'P84085', 'O31697', 'Q6L084', 'O17754',
#        'Q6L2P7', 'P76055', 'Q13769', 'P0A7J3', 'P23396', 'Q5SWQ8',
#        'Q6KZD4', 'P0AFX9', 'Q6L1M5', 'Q22857', 'P16989', 'Q21557',
#        'Q9VX88', 'D3Z645', 'Q9P2Y5', 'Q61712', 'Q9FKM2', 'O80934',
#        'R4YR45', 'P0CZ23', 'Q8R4V1', 'Q6KZ97', 'Q96BR5', 'Q3U7Z6',
#        'O02373', 'P91021', 'P61006', 'Q72JK8', 'Q72HA0', 'P46984',
#        'Q9CR68', 'R4YSC7', 'P54391', 'Q9BUH6', 'Q06682', 'Q9V7N5',
#        'Q99KS2', 'Q9CZ13', 'Q8BI72', 'R4YTT9', 'O16406', 'I7FXD9',
#        'Q14691', 'Q8BU88', 'R4YST8', 'Q9CQX6', 'Q6L1U0', 'Q9SAB3',
#        'Q9BT78', 'R4YNR7', 'P07395', 'P37051', 'P14802', 'Q9BX68',
#        'P81101', 'P56480', 'Q8VHM7', 'P42226', 'P0AEZ3', 'P20042',
#        'O14508', 'P30750', 'O08908', 'P28188', 'Q8CFD4', 'O95551',
#        'Q9NRY5', 'P35659', 'Q93ZG9', 'R4YMQ5', 'Q15814', 'Q745T7',
#        'O32199', 'Q9V439', 'Q72I39', 'Q8NDC0', 'R4YL22', 'Q9DCJ5',
#        'A6H5X4', 'P61960', 'Q9VH89', 'Q9XWV3', 'R4YL21', 'Q5Y5T2'],
#       dtype='<U10'), '../20250526-1 true and baseline vs dynamics performance/stats/accessions - largest improvement (baseline 2 vs dynamics 4).csv': array(['P23396', 'P21365', 'P03899', 'Q8MQ13', 'Q6L225', 'Q9H0U4',
#        'P81101', 'P53497', 'P00903', 'P33204', 'P0A8U0', 'Q7ZU67',
#        'P84085', 'A7MCK9', 'P62258', 'Q6Q546', 'P07487', 'P54167',
#        'R4YTT9', 'Q15907', 'Q7ZWE5', 'Q745T7', 'P46984', 'Q93WN0',
#        'G5EFV5', 'Q10651', 'Q72HJ9', 'P09734', 'P0AGB6', 'Q3E754',
#        'Q8W4H7', 'R4YR45', 'P61006', 'O31775', 'Q9LQK7', 'R4YPZ0',
#        'O04420', 'A1Z7A8', 'P28188', 'P25294', 'Q9LY74', 'Q72JK8',
#        'P0AFX4', 'Q20436', 'R4YMQ5', 'O05264', 'P53145', 'P0CF20',
#        'P27111', 'Q9C5U3', 'P0AAD6', 'P75853', 'R4YST8', 'R4YK80',
#        'P0AFE4', 'R4YUC2', 'R4YPI8', 'P10674', 'O65693', 'Q9DB28',
#        'Q17780', 'Q9LQK0', 'P54454', 'P10127', 'Q8W4M5', 'Q8BTU1',
#        'P40005', 'Q21557', 'Q9FK81', 'Q7T3G2', 'Q9U2F6', 'R4YQ94',
#        'R4YP88', 'I7FXD9', 'Q8BZ36', 'O34723', 'Q9NZ32', 'P28248',
#        'Q72GE1', 'Q3UI84', 'Q9U2W9', 'P42677', 'P28707', 'P29746',
#        'Q72K92', 'P53731', 'R4YLA8', 'Q6L2N1', 'P91910', 'D3Z645',
#        'P0A9W6', 'R4YTQ0', 'A0A077S9N1', 'Q9CPV4', 'O23553', 'P00950',
#        'Q01525', 'P0A6J8', 'P32939', 'R4YL61', 'Q9LFH5', 'Q9V7N5',
#        'R4YRB0', 'Q6L0L7', 'Q6L084', 'R4YP99', 'Q9GYR2', 'R4YLR6',
#        'Q11183', 'Q9V439', 'Q9CZP5', 'Q8L7B2', 'Q9XWV3', 'P13056',
#        'Q9SIE1', 'P0AC59', 'Q966G0', 'Q3UY68', 'Q96AD5', 'P08997',
#        'P53155', 'Q9VMP9', 'R4YSC7', 'Q8BPE4', 'A0A0R4J009', 'Q17796',
#        'A6H5X4', 'P30750', 'Q13637', 'Q12338', 'P14802', 'Q99JT9',
#        'Q9DCJ5', 'Q8I4E2', 'Q72K10', 'Q6L2C8', 'Q8NDC0', 'Q6L235',
#        'Q8K2B3', 'R4YTU2', 'Q0WTP1', 'P91182', 'A5PMP1', 'Q6L1G6',
#        'Q8R4V1', 'P35178', 'O61980', 'Q18186', 'O22832', 'R4YJC2'],
#       dtype='<U10')}

# %%
# GET INFOR FROM UNIPROTKB

all_available_accessions = set()
for src_file in accessions:
    available_accessions, _ = retriever.batch_retrieve(accessions[src_file])
    all_available_accessions.update(available_accessions)

print('Number of accessions:', len(all_available_accessions))
print(list(all_available_accessions)[:5])
# Out:
# P48036      : 100%|##########| 150/150 [00:12<00:00, 12.05it/s]
# Q5Y5T2      : 100%|##########| 150/150 [01:09<00:00,  2.15it/s]
# R4YJC2      : 100%|##########| 150/150 [01:10<00:00,  2.14it/s]
# Number of accessions: 325
# ['Q12338', 'G5EFV5', 'Q966C7', 'Q72IP3', 'O16406']

# %%
accessions_with_FT = []
FT_categories = []

for accession in all_available_accessions:
    # print(f' >> {accession}')
    unprotkb_file = f'{kb_dir}/{accession}.txt'

    with open(unprotkb_file, 'r') as f:
        content = f.read().split('\n')

    for line in content:
        if line.startswith('FT'):

            if line[5] != ' ':
                FT_categories.append(line.split()[1])

FT_categories = np.unique(FT_categories)

print('Number of unique categories for FT:', len(FT_categories))
print(FT_categories)
# Out:
# Number of unique categories for FT: 32
# ['ACT_SITE' 'BINDING' 'CARBOHYD' 'CHAIN' 'COILED' 'COMPBIAS' 'CONFLICT'
#  'CROSSLNK' 'DISULFID' 'DNA_BIND' 'DOMAIN' 'HELIX' 'INIT_MET' 'INTRAMEM'
#  'LIPID' 'MOD_RES' 'MOTIF' 'MUTAGEN' 'NON_TER' 'PROPEP' 'REGION' 'REPEAT'
#  'SIGNAL' 'SITE' 'STRAND' 'TOPO_DOM' 'TRANSIT' 'TRANSMEM' 'TURN' 'VARIANT'
#  'VAR_SEQ' 'ZN_FING']

# %%
all_FT_info = {}

for accession in available_accessions:
    print(f' >> {accession}')
    unprotkb_file = f'{kb_dir}/{accession}.txt'

    with open(unprotkb_file, 'r') as f:
        content = f.read().split('\n')

    FT_for_accession = {
        FT_category: [] for FT_category in FT_categories
    }
    for FT_category in FT_categories:

        resnums = None
        for line_idx, line in enumerate(content):
            if line.startswith(f'FT   {FT_category}'):
                resnums = line.split()[2]

                annotation = {}
                line_idx += 1
                while content[line_idx].startswith('FT') and content[line_idx][5] == ' ':
                    line = content[line_idx][21:]

                    if line.startswith('/'):
                        key = line.split('=')[0][1:]
                        annotation[key] = line.split('=')[1].strip('"')
                    else:
                        annotation[key] += ' '
                        annotation[key] += line.strip('"')

                    line_idx += 1

            if resnums is not None:
                FT_for_accession[FT_category].append({
                    'resnums': resnums,
                    'annotation': annotation
                })
                resnums = None

    # remove if empty
    FT_for_accession = {
        k: v for k, v in FT_for_accession.items()
        if v
    }

    all_FT_info[accession] = FT_for_accession
    print(list(FT_for_accession))
# Out:
#  >> P23396
# ['CHAIN', 'COMPBIAS', 'CONFLICT', 'CROSSLNK', 'DOMAIN', 'HELIX', 'INIT_MET', 'MOD_RES', 'MUTAGEN', 'REGION', 'STRAND', 'TURN', 'VAR_SEQ']
#  >> P21365
# ['CHAIN', 'CONFLICT', 'TOPO_DOM', 'TRANSMEM', 'VARIANT']
#  >> P03899
# ['CHAIN', 'CONFLICT', 'HELIX', 'STRAND', 'TRANSMEM']
#  >> Q8MQ13
# ['DOMAIN', 'REGION']
#  >> Q6L225
# ['BINDING', 'CHAIN', 'ZN_FING']
#  >> Q9H0U4
# ['BINDING', 'CHAIN', 'HELIX', 'LIPID', 'MOD_RES', 'MOTIF', 'MUTAGEN', 'REGION', 'STRAND', 'TURN']
#  >> P81101
# ['CHAIN', 'CONFLICT', 'INIT_MET']
#  >> P53497
# ['CHAIN', 'INIT_MET', 'MOD_RES']
#  >> P00903
# ['ACT_SITE', 'CHAIN', 'DOMAIN', 'MUTAGEN']
#  >> P33204
# ['CHAIN']
#  >> P0A8U0
# ['CHAIN', 'HELIX', 'STRAND', 'TURN']
#  >> Q7ZU67
# ['COMPBIAS', 'DOMAIN', 'MOTIF', 'REGION']
#  >> P84085
# ['BINDING', 'CHAIN', 'HELIX', 'INIT_MET', 'LIPID', 'STRAND', 'TURN']
#  >> A7MCK9
# ['DOMAIN', 'TRANSMEM']
#  >> P62258
# ['CHAIN', 'CONFLICT', 'CROSSLNK', 'HELIX', 'MOD_RES', 'MUTAGEN', 'REGION', 'SITE', 'STRAND', 'TURN', 'VAR_SEQ']
#  >> Q6Q546
# ['CHAIN', 'CONFLICT', 'DOMAIN', 'HELIX', 'STRAND', 'TURN']
#  >> P07487
# ['ACT_SITE', 'BINDING', 'CHAIN', 'CONFLICT', 'MOD_RES', 'SITE', 'VARIANT']
#  >> P54167
# ['ACT_SITE', 'BINDING', 'CHAIN', 'SITE']
#  >> R4YTT9
# ['BINDING', 'DOMAIN']
#  >> Q15907
# ['BINDING', 'CHAIN', 'CONFLICT', 'HELIX', 'INIT_MET', 'LIPID', 'MOD_RES', 'MOTIF', 'MUTAGEN', 'PROPEP', 'REGION', 'STRAND', 'TURN', 'VARIANT', 'VAR_SEQ']
#  >> Q7ZWE5
# ['COILED', 'DOMAIN']
#  >> Q745T7
# ['DOMAIN']
#  >> P46984
# ['CHAIN', 'COMPBIAS', 'HELIX', 'REGION', 'STRAND', 'TURN']
#  >> Q93WN0
# ['BINDING', 'CHAIN', 'CONFLICT', 'INIT_MET', 'MOD_RES']
#  >> G5EFV5
# ['ACT_SITE', 'BINDING', 'CHAIN', 'COMPBIAS', 'DOMAIN', 'MOD_RES', 'MUTAGEN', 'REGION']
#  >> Q10651
# ['BINDING', 'CARBOHYD', 'CHAIN', 'COMPBIAS', 'DISULFID', 'DOMAIN', 'HELIX', 'MOTIF', 'MUTAGEN', 'REGION', 'SIGNAL', 'STRAND', 'TOPO_DOM', 'TRANSMEM', 'TURN', 'VAR_SEQ']
#  >> Q72HJ9
# ['DOMAIN']
#  >> P09734
# ['ACT_SITE', 'BINDING', 'CHAIN']
#  >> P0AGB6
# ['CHAIN', 'DNA_BIND', 'HELIX', 'MOTIF', 'MUTAGEN', 'REGION', 'STRAND', 'TURN']
#  >> Q3E754
# ['CHAIN', 'MOD_RES']
#  >> Q8W4H7
# ['BINDING', 'CHAIN', 'CONFLICT', 'CROSSLNK', 'DOMAIN', 'MOD_RES', 'REGION']
#  >> R4YR45
# ['BINDING', 'DOMAIN', 'TRANSMEM']
#  >> P61006
# ['BINDING', 'CHAIN', 'CONFLICT', 'HELIX', 'LIPID', 'MOD_RES', 'MOTIF', 'MUTAGEN', 'PROPEP', 'STRAND', 'TURN', 'VAR_SEQ']
#  >> O31775
# ['ACT_SITE', 'BINDING', 'CHAIN', 'HELIX', 'MUTAGEN', 'STRAND', 'TURN']
#  >> Q9LQK7
# ['CHAIN', 'CONFLICT', 'TRANSIT']
#  >> R4YPZ0
# ['DOMAIN', 'TRANSMEM']
#  >> O04420
# ['ACT_SITE', 'BINDING', 'CHAIN', 'CONFLICT', 'INIT_MET', 'MOD_RES', 'MOTIF']
#  >> A1Z7A8
# ['CHAIN', 'COMPBIAS', 'CONFLICT', 'REGION', 'VAR_SEQ']
#  >> P28188
# ['BINDING', 'CHAIN', 'LIPID', 'MOTIF', 'MUTAGEN', 'REGION']
#  >> P25294
# ['CHAIN', 'COMPBIAS', 'DOMAIN', 'HELIX', 'MOD_RES', 'REGION', 'STRAND', 'TURN']
#  >> Q9LY74
# ['CHAIN', 'CONFLICT', 'MUTAGEN', 'REGION', 'TOPO_DOM', 'TRANSIT', 'TRANSMEM']
#  >> Q72JK8
# ['BINDING', 'CHAIN', 'SITE']
#  >> P0AFX4
# ['CHAIN', 'HELIX', 'REGION']
#  >> Q20436
# ['DOMAIN']
#  >> R4YMQ5
# ['BINDING', 'DOMAIN']
#  >> O05264
# ['BINDING', 'CHAIN']
#  >> P53145
# ['BINDING', 'CHAIN', 'COMPBIAS', 'DOMAIN', 'MOD_RES', 'MUTAGEN', 'REGION']
#  >> P0CF20
# ['CHAIN', 'TRANSMEM']
#  >> P27111
# ['CHAIN', 'DNA_BIND', 'DOMAIN', 'HELIX', 'STRAND', 'TURN']
#  >> Q9C5U3
# ['BINDING', 'CHAIN', 'CROSSLNK', 'INIT_MET', 'MOD_RES']
#  >> P0AAD6
# ['CHAIN', 'TOPO_DOM', 'TRANSMEM']
#  >> P75853
# ['CHAIN', 'HELIX', 'SIGNAL', 'STRAND']
#  >> R4YST8
# ['DOMAIN']
#  >> R4YK80
# ['DOMAIN', 'TRANSMEM']
#  >> P0AFE4
# ['CHAIN', 'CONFLICT', 'HELIX', 'MUTAGEN', 'TOPO_DOM', 'TRANSMEM']
#  >> R4YUC2
# ['DOMAIN']
#  >> R4YPI8
# ['DOMAIN']
#  >> P10674
# ['CARBOHYD', 'CHAIN', 'DOMAIN', 'HELIX', 'LIPID', 'PROPEP', 'SIGNAL', 'STRAND', 'TURN']
#  >> O65693
# ['CHAIN', 'COMPBIAS', 'REGION', 'TRANSIT']
#  >> Q9DB28
# ['CHAIN', 'CONFLICT', 'MOD_RES']
#  >> Q17780
# []
#  >> Q9LQK0
# ['BINDING', 'CHAIN', 'COMPBIAS', 'CONFLICT', 'DOMAIN', 'REGION']
#  >> P54454
# ['CHAIN', 'DOMAIN']
#  >> P10127
# ['BINDING', 'CHAIN', 'CONFLICT']
#  >> Q8W4M5
# ['ACT_SITE', 'BINDING', 'CHAIN', 'MOD_RES', 'SITE']
#  >> Q8BTU1
# ['CHAIN', 'CONFLICT', 'VAR_SEQ']
#  >> P40005
# ['CHAIN', 'COILED', 'CONFLICT']
#  >> Q21557
# ['CHAIN']
#  >> Q9FK81
# ['BINDING', 'CHAIN', 'DOMAIN', 'HELIX', 'STRAND', 'TURN']
#  >> Q7T3G2
# ['DOMAIN', 'SITE']
#  >> Q9U2F6
# ['COILED', 'COMPBIAS', 'REGION']
#  >> R4YQ94
# ['DOMAIN']
#  >> R4YP88
# ['BINDING', 'DOMAIN']
#  >> I7FXD9
# ['NON_TER']
#  >> Q8BZ36
# ['CHAIN', 'COILED', 'COMPBIAS', 'CONFLICT', 'DOMAIN', 'REGION', 'VAR_SEQ']
#  >> O34723
# ['CHAIN', 'DNA_BIND', 'DOMAIN', 'HELIX', 'MOD_RES', 'STRAND', 'TURN']
#  >> Q9NZ32
# ['CHAIN', 'CONFLICT']
#  >> P28248
# ['ACT_SITE', 'BINDING', 'CHAIN', 'HELIX', 'MUTAGEN', 'STRAND', 'TURN']
#  >> Q72GE1
# ['DOMAIN', 'TRANSMEM']
#  >> Q3UI84
# ['DOMAIN', 'TRANSMEM']
#  >> Q9U2W9
# ['DOMAIN']
#  >> P42677
# ['BINDING', 'CHAIN', 'COMPBIAS', 'CONFLICT', 'HELIX', 'INIT_MET', 'MOD_RES', 'REGION', 'STRAND', 'ZN_FING']
#  >> P28707
# ['CHAIN', 'COMPBIAS', 'DOMAIN', 'INIT_MET', 'MOD_RES', 'REGION', 'REPEAT', 'STRAND', 'TURN']
#  >> P29746
# ['CHAIN', 'COMPBIAS', 'MOD_RES', 'REGION']
#  >> Q72K92
# ['COILED']
#  >> P53731
# ['CHAIN', 'MOD_RES']
#  >> R4YLA8
# ['DOMAIN']
#  >> Q6L2N1
# ['DOMAIN']
#  >> P91910
# ['ACT_SITE', 'BINDING', 'CHAIN', 'HELIX', 'MOD_RES', 'MUTAGEN', 'SITE', 'STRAND', 'TURN']
#  >> D3Z645
# ['DOMAIN']
#  >> P0A9W6
# ['CHAIN', 'HELIX', 'STRAND', 'TURN']
#  >> R4YTQ0
# ['DOMAIN']
#  >> A0A077S9N1
# ['CHAIN', 'DOMAIN', 'SIGNAL']
#  >> Q9CPV4
# ['CHAIN', 'CONFLICT', 'DOMAIN', 'MOD_RES', 'VAR_SEQ']
#  >> O23553
# ['ACT_SITE', 'BINDING', 'CHAIN', 'COMPBIAS', 'REGION', 'TRANSIT']
#  >> P00950
# ['ACT_SITE', 'BINDING', 'CHAIN', 'CROSSLNK', 'HELIX', 'INIT_MET', 'MOD_RES', 'MUTAGEN', 'SITE', 'STRAND', 'TURN']
#  >> Q01525
# ['CHAIN', 'CONFLICT', 'HELIX', 'MOD_RES', 'STRAND', 'TURN']
#  >> P0A6J8
# ['BINDING', 'CHAIN', 'DOMAIN']
#  >> P32939
# ['BINDING', 'CHAIN', 'CROSSLNK', 'HELIX', 'LIPID', 'MOD_RES', 'MOTIF', 'MUTAGEN', 'STRAND', 'TURN']
#  >> R4YL61
# ['DOMAIN']
#  >> Q9LFH5
# ['CHAIN']
#  >> Q9V7N5
# ['CHAIN', 'COMPBIAS', 'CONFLICT', 'REGION', 'VAR_SEQ']
#  >> R4YRB0
# ['DOMAIN']
#  >> Q6L0L7
# ['ACT_SITE', 'BINDING', 'DOMAIN', 'REGION']
#  >> Q6L084
# ['DOMAIN']
#  >> R4YP99
# ['DOMAIN', 'TRANSMEM']
#  >> Q9GYR2
# []
#  >> R4YLR6
# ['DOMAIN']
#  >> Q11183
# ['CHAIN', 'DOMAIN']
#  >> Q9V439
# ['CHAIN']
#  >> Q9CZP5
# ['BINDING', 'CHAIN', 'HELIX', 'INIT_MET', 'MOD_RES', 'STRAND', 'TOPO_DOM', 'TRANSMEM', 'TURN']
#  >> Q8L7B2
# ['ACT_SITE', 'CARBOHYD', 'CHAIN', 'CONFLICT', 'DISULFID', 'MOTIF', 'SIGNAL']
#  >> Q9XWV3
# ['CHAIN']
#  >> P13056
# ['CHAIN', 'CONFLICT', 'CROSSLNK', 'DNA_BIND', 'DOMAIN', 'MOD_RES', 'REGION', 'VAR_SEQ', 'ZN_FING']
#  >> Q9SIE1
# ['BINDING', 'CHAIN', 'CONFLICT', 'HELIX', 'MOD_RES', 'STRAND', 'TRANSIT', 'TURN', 'VAR_SEQ']
#  >> P0AC59
# ['CHAIN', 'CONFLICT', 'DISULFID', 'DOMAIN', 'HELIX', 'STRAND', 'TURN']
#  >> Q966G0
# []
#  >> Q3UY68
# ['BINDING', 'DOMAIN']
#  >> Q96AD5
# ['ACT_SITE', 'CARBOHYD', 'CHAIN', 'CONFLICT', 'CROSSLNK', 'DOMAIN', 'MOD_RES', 'MOTIF', 'MUTAGEN', 'REGION', 'TOPO_DOM', 'TRANSMEM', 'VARIANT', 'VAR_SEQ']
#  >> P08997
# ['ACT_SITE', 'CHAIN', 'HELIX', 'STRAND', 'TURN']
#  >> P53155
# ['CHAIN', 'COMPBIAS', 'CONFLICT', 'HELIX', 'REGION', 'STRAND', 'TURN']
#  >> Q9VMP9
# ['ACT_SITE', 'CHAIN']
#  >> R4YSC7
# ['DOMAIN', 'TRANSMEM']
#  >> Q8BPE4
# ['CHAIN', 'TOPO_DOM', 'TRANSMEM']
#  >> A0A0R4J009
# []
#  >> Q17796
# ['COMPBIAS', 'DOMAIN', 'REGION']
#  >> A6H5X4
# ['CHAIN', 'COMPBIAS', 'CONFLICT', 'REGION', 'VAR_SEQ', 'ZN_FING']
#  >> P30750
# ['BINDING', 'CHAIN', 'CONFLICT', 'DOMAIN', 'HELIX', 'MUTAGEN', 'REGION', 'STRAND', 'TURN']
#  >> Q13637
# ['BINDING', 'CHAIN', 'HELIX', 'INIT_MET', 'LIPID', 'MOD_RES', 'MOTIF', 'MUTAGEN', 'REGION', 'STRAND', 'TURN', 'VARIANT']
#  >> Q12338
# ['CHAIN', 'COMPBIAS', 'CONFLICT', 'REGION']
#  >> P14802
# ['ACT_SITE', 'BINDING', 'CHAIN']
#  >> Q99JT9
# ['BINDING', 'CHAIN', 'HELIX', 'REGION', 'STRAND', 'TURN']
#  >> Q9DCJ5
# ['CHAIN', 'DISULFID', 'DOMAIN', 'HELIX', 'INIT_MET', 'MOTIF', 'STRAND', 'TURN']
#  >> Q8I4E2
# ['CHAIN', 'COMPBIAS', 'DOMAIN', 'MUTAGEN', 'REGION', 'VAR_SEQ']
#  >> Q72K10
# []
#  >> Q6L2C8
# ['COMPBIAS', 'DOMAIN', 'REGION']
#  >> Q8NDC0
# ['CHAIN', 'COMPBIAS', 'INIT_MET', 'MOD_RES', 'REGION']
#  >> Q6L235
# ['DOMAIN']
#  >> Q8K2B3
# ['ACT_SITE', 'BINDING', 'CHAIN', 'CONFLICT', 'MOD_RES', 'TRANSIT']
#  >> R4YTU2
# ['COILED', 'DOMAIN', 'TRANSMEM']
#  >> Q0WTP1
# ['CHAIN', 'COILED', 'CONFLICT']
#  >> P91182
# ['COMPBIAS', 'DOMAIN', 'REGION']
#  >> A5PMP1
# ['ACT_SITE', 'DOMAIN']
#  >> Q6L1G6
# ['BINDING', 'DOMAIN']
#  >> Q8R4V1
# ['CARBOHYD', 'CHAIN', 'DISULFID', 'DOMAIN', 'MOD_RES', 'SIGNAL', 'TOPO_DOM', 'TRANSMEM', 'VAR_SEQ']
#  >> P35178
# ['CHAIN', 'COMPBIAS', 'HELIX', 'MOD_RES', 'REGION', 'STRAND', 'TURN']
#  >> O61980
# ['COILED', 'COMPBIAS', 'DOMAIN', 'REGION']
#  >> Q18186
# ['DOMAIN']
#  >> O22832
# ['BINDING', 'CHAIN', 'CONFLICT', 'MOD_RES', 'MUTAGEN', 'TRANSIT']
#  >> R4YJC2
# ['DOMAIN']

# %%
# SAVE STATS

with open(f'{stats_dir}/uniprotkb_info - {tag}.json', 'w') as f:
    json.dump(all_FT_info, f, indent=4)
